# %%
import sys
import os
import ast
import re
import glob
import json
import inspect
import math
import quantities

from functools import reduce # forward compatibility
import operator

import gc
import numpy
import scipy

import pylab
import matplotlib
import matplotlib.pyplot as plt

import quantities as qt

from parameters import ParameterSet

import mozaik
import mozaik.controller
from mozaik.visualization.plotting import *
from mozaik.analysis.technical import NeuronAnnotationsToPerNeuronValues
from mozaik.analysis.analysis import *
from mozaik.analysis.vision import *
from mozaik.storage.queries import *
from mozaik.storage.datastore import PickledDataStore

from mozaik.tools.mozaik_parametrized import colapse

import neo

# %%
def select_ids_by_position(positions, sheet_ids, radius=[0,0], box=[], reverse=False, origin=[[0.],[0.],[0.]]):
	selected_ids = []
	distances = []
	min_radius = radius[0]
	max_radius = radius[1]

	for i in sheet_ids:
		a = numpy.array((positions[0][i],positions[1][i],positions[2][i]))
		# print a

		if len(box)>1:
			# Ex box: [ [-.3,.0], [.3,-.4] ]
			# Ex a: [ [-0.10769224], [ 0.16841423], [ 0. ] ]
			# print box[0][0], a[0], box[1][0], "      ", box[0][1], a[1], box[1][1]
			if a[0]>=box[0][0] and a[0]<=box[1][0] and a[1]>=box[0][1] and a[1]<=box[1][1]:
				# print a[0], "   ", a[1]
				selected_ids.append(i[0])
				distances.append(0.0)
		else:
			# print a # from origin
			l = numpy.linalg.norm(origin-a)

			# print "distance",l
			# print abs(l),">",min_radius,"and", abs(l), "<", max_radius
			if abs(l)>min_radius and abs(l)<max_radius:
				# print abs(l),">",min_radius,"and", abs(l), "<", max_radius, "TAKEN"
				# print i
				selected_ids.append(i[0])
				distances.append(l)

	# sort by distance
	# print len(selected_ids)
	# print distances
	return [x for (y,x) in sorted(zip(distances,selected_ids), key=lambda pair:pair[0], reverse=reverse)]




def LFP(data_store, sheet, folder, stimulus, parameter, tip=[.0,.0,.0], sigma=0.300, ylim=[0.,-1.], addon="", color='black' ):
	import matplotlib as ml
	import quantities as pq
	#print inspect.stack()[0][3]
	print "folder: ",folder
	print "sheet: ",sheet

	segs = sorted( 
		param_filter_query(data_store, st_name=stimulus, sheet_name=sheet).get_segments(), 
		key = lambda x : getattr(MozaikParametrized.idd(x.annotations['stimulus']), parameter) 
	)
	print len(segs)
	# for s in segs:
	# 	s.load_full()

	ids = param_filter_query(data_store, sheet_name=sheet, st_name=stimulus).get_segments()[0].get_stored_vm_ids()
	if ids == None or len(ids)<1:
		print "No Vm recorded.\n"
		return

	print "Recorded neurons:", len(ids), ids
	# 900 neurons over 6000 micrometers, 200 micrometers interval

	sheet_indexes = data_store.get_sheet_indexes(sheet_name=sheet, neuron_ids=ids)

	positions = data_store.get_neuron_postions()[sheet]
	print positions.shape # all 10800

	# take the positions of the ids
	ids_positions = numpy.transpose(positions)[sheet_indexes,:]
	print ids_positions.shape
	print ids_positions

	# Pre-compute distances from the LFP tip
	distances = []
	for i in range(len(ids)):
		distances.append( numpy.linalg.norm( numpy.array(ids_positions[i][0]) - numpy.array(tip) ) ) 
	distances = numpy.array(distances)
	print "distances:", len(distances), distances

	# ##############################
	# LFP
	# tip = [[x],[y],[.0]]
	# For each recorded cell:
	# Gaussianly weight it by its distance from tip
	# produce the currents
	# Divide the whole by the norm factor (area): 4 * numpy.pi * sigma

	# 95% of the LFP signal is a result of all exc and inh cells conductances from 250um radius from the tip of the electrode (Katzner et al. 2009).
	# Mostly excitatory neurons are relevant for the LFP (because of their geometry) Bartos
	# Therefore we include all recorded cells but account for the distance-dependent contribution weighting currents /r^2
	# We assume that the electrode has been placed in the cortical coordinates <tip>
	# Given that the current V1 orientation map has a pixel for each 100 um, a reasonable way to look at a neighborhood is in a radius of 300 um

	print "LFP electrode tip location (x,y) in degrees:", tip

	# Gather vm and conductances
	segs = sorted( 
		param_filter_query(data_store, st_name=stimulus, sheet_name=sheet).get_segments(), 
		key = lambda x : getattr(MozaikParametrized.idd(x.annotations['stimulus']), parameter) 
	)
	ticks = set([])
	for x in segs:
		ticks.add( getattr(MozaikParametrized.idd(x.annotations['stimulus']), parameter) )
	ticks = sorted(ticks)
	num_ticks = len( ticks )
	print ticks
	trials = len(segs) / num_ticks
	print "trials:",trials

	pop_vm = []
	pop_gsyn_e = []
	pop_gsyn_i = []
	print "Number of neurons considering" , len(ids)
	for n,idd in enumerate(ids):
		print "idd", idd
		full_vm = [s.get_vm(idd) for s in segs] # all segments
		full_gsyn_es = [s.get_esyn(idd) for s in segs]
		full_gsyn_is = [s.get_isyn(idd) for s in segs]
		print "len full_gsyn_e", len(full_gsyn_es) # segments = stimuli * trials
		print "shape gsyn_e[0]", full_gsyn_es[0].shape # stimulus lenght
		# mean input over trials
		mean_full_vm = numpy.zeros((num_ticks, full_vm[0].shape[0])) # init
		mean_full_gsyn_e = numpy.zeros((num_ticks, full_gsyn_es[0].shape[0])) # init
		mean_full_gsyn_i = numpy.zeros((num_ticks, full_gsyn_es[0].shape[0]))
		# print "shape mean_full_gsyn_e/i", mean_full_gsyn_e.shape
		sampling_period = full_gsyn_es[0].sampling_period
		t_stop = float(full_gsyn_es[0].t_stop - sampling_period) # 200.0
		t_start = float(full_gsyn_es[0].t_start)
		time_axis = numpy.arange(0, len(full_gsyn_es[0]), 1) / float(len(full_gsyn_es[0])) * abs(t_start-t_stop) + t_start
		# sum by size
		t = 0
		for v,e,i in zip(full_vm, full_gsyn_es, full_gsyn_is):
			s = int(t/trials)
			v = v.rescale(quantities.mV) 
			e = e.rescale(mozaik.tools.units.nS) # NEST is in nS, PyNN is in uS
			i = i.rescale(mozaik.tools.units.nS) # NEST is in nS, PyNN is in uS
			mean_full_vm[s] = mean_full_vm[s] + numpy.array(v.tolist())
			mean_full_gsyn_e[s] = mean_full_gsyn_e[s] + numpy.array(e.tolist())
			mean_full_gsyn_i[s] = mean_full_gsyn_i[s] + numpy.array(i.tolist())
			t = t+1

		# average by trials
		for st in range(num_ticks):
			mean_full_vm[st] = mean_full_vm[st] / trials
			mean_full_gsyn_e[st] = mean_full_gsyn_e[st] / trials
			mean_full_gsyn_i[st] = mean_full_gsyn_i[st] / trials

		pop_vm.append(mean_full_vm)
		pop_gsyn_e.append(mean_full_gsyn_e)
		pop_gsyn_i.append(mean_full_gsyn_i)

	pop_v = numpy.array(pop_vm)
	pop_e = numpy.array(pop_gsyn_e)
	pop_i = numpy.array(pop_gsyn_i)

	# Produce the current for each cell for this time interval, with the Ohm law:
	# I = ge(V-Ee) + gi(V+Ei)
	# where 
	# Ee is the equilibrium for exc, which is 0.0
	# Ei is the equilibrium for inh, which is -80.0
	i = pop_e*(pop_v-0.0) + pop_i*(pop_v-80.0)
	# i = pop_e*(pop_v-0.0) + 0.3*pop_i*(pop_v-80.0)
	# i = pop_e*(pop_v-0.0) # only exc
	# the LFP is the result of cells' currents divided by the distance
	print numpy.shape(distances)
	print numpy.shape(i)
	i = i#/distances
	sum_i = numpy.sum(i, axis=0 )
	lfp = sum_i/(4*numpy.pi*sigma) #
	lfp /= 1000. # from milli to micro
	print "LFP:", lfp.shape, lfp.mean(), lfp.min(), lfp.max()
	# print lfp
	# lfp = np.convolve(lfp, np.ones((10,))/10, mode='valid') # moving avg or running mean implemented as a convolution over steps of 10, divided by 10
	# lfp = np.convolve(lfp, np.ones((10,))/10, mode='valid') # moving avg or running mean implemented as a convolution over steps of 10, divided by 10

	#plot the LFP for each stimulus
	for s in range(num_ticks):
		# for each stimulus plot the average conductance per cell over time
		matplotlib.rcParams.update({'font.size':22})
		fig,ax = plt.subplots()

		ax.plot( range(0,len(lfp[s])), lfp[s], color=color, linewidth=3 )

		# ax.set_ylim([lfp.min(), lfp.max()])
		ax.set_xlim([0,150])
		ax.set_ylim(ylim)
		ax.set_ylabel( "LFP (uV)" )
		ax.set_xlabel( "Time (us)" )
		ax.spines['right'].set_visible(False)
		ax.spines['top'].set_visible(False)
		ax.xaxis.set_ticks_position('bottom')
		ax.xaxis.set_ticks(ticks, ticks)
		ax.yaxis.set_ticks_position('left')

		# text
		plt.tight_layout()
		plt.savefig( folder+"/TimecourseLFP_"+"_"+parameter+"_"+str(ticks[s])+"_"+addon+".svg", dpi=200, transparent=True )
		fig.clf()
		plt.close()
		# garbage
		gc.collect()

# %%
data_store = PickledDataStore(load=True,parameters=ParameterSet({'root_directory':'/home/antolikjan/remote/UNIC/dev/pkg/mozaik/mozaik/contrib/New/20190912-113106[param_FINAL.defaults]CombinationParamSearch{sheets.l4_cortex_exc.K:[1000]}/SelfSustainedPushPull_ParameterSearch_____sheets.l4_cortex_exc.K:1000','store_stimuli': False}),replace=True)

# %%
# [0.14999999999999991,0.15000000000000002]
dsv = param_filter_query(data_store,st_name='FlashedInterruptedBar',st_y=0.15)    
dsv.print_content()
print data_store.get_segments()[160].annotations
# Out:
# INFO:Mozaik:DSV info:
# INFO:Mozaik:   Number of recordings: 600
# INFO:Mozaik:     FlashedInterruptedBar : 600
# INFO:Mozaik:   Number of ADS: 30
# INFO:Mozaik:     PerNeuronValue : 30
# {'stimulus': '{"module_path" :"mozaik.stimuli.vision.topographica_based","background_luminance":50.0, "density":10.0, "direct_stimulation_name":\'None\', "disalignment":0, "duration":2002, "flash_duration":2002, "frame_duration":7, "gap_length":0.6, "length":20, "location_x":0.0, "location_y":0.0, "name":\'FlashedInterruptedBar\', "orientation":0, "relative_luminance":1.0, "size_x":11.0, "size_y":11.0, "trial":0, "width":0.3125, "x":4.5924254968025736e-17, "y":0.74999999999999989}', 'sheet_name': 'V1_Inh_L4'}

# %%
f = '/home/antolikjan/remote/UNIC/dev/pkg/mozaik/mozaik/contrib/New/20190912-113106[param_FINAL.defaults]CombinationParamSearch{sheets.l4_cortex_exc.K:[1000]}/SelfSustainedPushPull_ParameterSearch_____sheets.l4_cortex_exc.K:1000'

dsv = param_filter_query(data_store,st_name='DriftingSinusoidalGratingRing')    
dsv.print_content()

s = 'V1_Exc_L4'
addon = 'L4'
color = 'r'

LFP(
    data_store=dsv,
    sheet=s, 
    folder=f, 
    stimulus='DriftingSinusoidalGratingRing',
    parameter="inner_appareture_radius",
    tip = [.0,.0,.0], # CENTER box in which to search a centroid for LFP to measure the conductance effect in lfp_sheet
    # tip_box = [[0.,0.],[0.,0.]], # box in which to search a centroid for LFP to measure the conductance effect in lfp_sheet
    # tip_box = [[0.,0.],[0.,0.]], # box in which to search a centroid for LFP to measure the conductance effect in lfp_sheet
    sigma = 0.4, #   mm, since 1mm = 1deg in this cortical space (spikes from the center of sheet)
    # sigma = 0.1, # [0.1, 0.01] # Dobiszewski_et_al2012.pdf
    # sigma = 0.25, # 0.25 Bartos et al.
    ylim=None,
    addon = addon + "_center",
    color = color,
)

s = 'V1_Exc_L2/3'
addon = 'L23'
color = 'r'

LFP(
    data_store=dsv,
    sheet=s, 
    folder=f, 
    stimulus='DriftingSinusoidalGratingRing',
    parameter="inner_appareture_radius",
    tip = [.0,.0,.0], # CENTER box in which to search a centroid for LFP to measure the conductance effect in lfp_sheet
    # tip_box = [[0.,0.],[0.,0.]], # box in which to search a centroid for LFP to measure the conductance effect in lfp_sheet
    # tip_box = [[0.,0.],[0.,0.]], # box in which to search a centroid for LFP to measure the conductance effect in lfp_sheet
    sigma = 0.4, #   mm, since 1mm = 1deg in this cortical space (spikes from the center of sheet)
    # sigma = 0.1, # [0.1, 0.01] # Dobiszewski_et_al2012.pdf
    # sigma = 0.25, # 0.25 Bartos et al.
    ylim=None,
    addon = addon + "_center",
    color = color,
)
# Out:
# INFO:Mozaik:DSV info:
# INFO:Mozaik:   Number of recordings: 1440
# INFO:Mozaik:     DriftingSinusoidalGratingRing : 1440
# INFO:Mozaik:   Number of ADS: 240
# INFO:Mozaik:     PerNeuronValue : 240
# folder:  /home/antolikjan/remote/UNIC/dev/pkg/mozaik/mozaik/contrib/New/20190912-113106[param_FINAL.defaults]CombinationParamSearch{sheets.l4_cortex_exc.K:[1000]}/SelfSustainedPushPull_ParameterSearch_____sheets.l4_cortex_exc.K:1000
# sheet:  V1_Exc_L4
# 120
# Recorded neurons: 225 [16064 25600 31936 31873 32065 32705 34241 37313 25346 33666 18755 22659
#  25859 35587 17924 29636 29764 37316 19077 22341 32133 37573 16390 23494
#  26950 28230 33222 37126 37318 31943 20168 25160 33864 23625 25865 28233
#  29001 17226 23691 31435 23692 24012 26060 19917 36301 24270 25614 25934
#  29454 36686 38094 38606 27087 32527 35343 21264 35344 28945 31569 33873
#  35217 37009 17170 18706 20882 29906 30098 35282 28307 31891 32019 19732
#  31892 24085 28309 30549 17302 19734 26839 30743 38039 17241 20633 28057
#  28249 30617 37657 21914 30874 35418 38490 19739 25883 26779 36059 17884
#  29532 17501 29085 33054 19551 26143 27167 30239 35935 16608 26912 29024
#  31712 34208 36064 27425 29217 30305 36194 20451 20708 25892 30244 30564
#  31588 36452 37284 23589 30693 37733 25638 30054 30566 36134 21607 34663
#  36519 19560 26024 26792 33000 36200 21929 20138 21610 25002 25834 28842
#  22827 27243 31275 22828 23916 24172 38444 15405 32429 15022 26030 32494
#  34606 37166 22639 23791 29295 29551 34415 36015 15856 21808 25328 31152
#  32432 38640 29425 29681 36337 15986 16690 18674 18994 21554 32626 34930
#  38002 19059 19635 28211 34739 18228 22260 24052 28852 35700 37364 38516
#  30901 33781 35381 23990 28918 29366 31286 22327 22136 23864 24760 33528
#  19129 24569 25273 26425 31865 18618 29946 33082 36730 38139 15164 16572
#  32316 34876 38524 19453 27389 27070 33278 17919 31359]
# (3, 24000)
# (225, 3)
# [[-0.68587985 -1.09420072  0.        ]
#  [-1.09141914 -1.49321862  0.        ]
#  [ 0.89770822 -1.08203647  0.        ]
#  [ 0.2896311   0.71105957  0.        ]
#  [ 0.48475044 -1.31203257  0.        ]
#  [ 1.10131122 -1.30447898  0.        ]
#  [-1.09392995 -0.49190048  0.        ]
#  [-1.11120479  0.69351102  0.        ]
#  [ 0.49266821  0.30359017  0.        ]
#  [-0.49797789  0.11195162  0.        ]
#  [ 0.69111219  0.29295274  0.        ]
#  [ 0.49847998 -0.31211053  0.        ]
#  [-0.2885003   1.3036214   0.        ]
#  [-0.09399457 -0.09291042  0.        ]
#  [-0.47622644 -0.3001014   0.        ]
#  [-0.90473246 -0.09654748  0.        ]
#  [ 0.10278371 -0.69581337  0.        ]
#  [ 0.50549338  0.11750314  0.        ]
#  [ 0.11818368 -0.1143792   0.        ]
#  [-0.29841251 -1.30418566  0.        ]
#  [ 0.69474502 -1.09458069  0.        ]
#  [ 0.07531962 -0.30501395  0.        ]
#  [ 0.72901064  0.9125716   0.        ]
#  [-1.29768878 -1.50910399  0.        ]
#  [-0.90718986  0.90578214  0.        ]
#  [ 0.52006569 -1.10185704  0.        ]
#  [-1.31308817 -0.90620726  0.        ]
#  [-1.28772261  0.10638844  0.        ]
#  [-0.6956618   0.310096    0.        ]
#  [ 0.71832644 -1.51350366  0.        ]
#  [ 0.07724622  0.28698046  0.        ]
#  [ 0.68427281 -1.31479924  0.        ]
#  [ 0.09692377 -1.30409029  0.        ]
#  [-0.89526833  0.49070633  0.        ]
#  [-1.49403061  0.11219859  0.        ]
#  [-0.51809996 -1.3062834   0.        ]
#  [-1.09828266 -1.29546085  0.        ]
#  [ 0.70161975 -0.10749216  0.        ]
#  [-0.29140016 -0.101805    0.        ]
#  [-0.11884329 -1.29255607  0.        ]
#  [ 0.50293124  0.50455257  0.        ]
#  [ 1.29853632  0.90221359  0.        ]
#  [-0.10304401  0.31657325  0.        ]
#  [-1.07811739  0.49711967  0.        ]
#  [ 0.90870851 -0.09187352  0.        ]
#  [ 1.29633537 -1.50457953  0.        ]
#  [-0.52324454  0.50275099  0.        ]
#  [ 0.50104569 -0.88944452  0.        ]
#  [-0.31949039 -0.90736925  0.        ]
#  [-0.10136878  0.10075496  0.        ]
#  [ 1.29141972  1.09794087  0.        ]
#  [-1.30851647  0.49227691  0.        ]
#  [ 0.89834613  0.48354233  0.        ]
#  [-0.32511743  0.28960785  0.        ]
#  [ 1.11999829  0.88530302  0.        ]
#  [-1.49599808  1.30103436  0.        ]
#  [-0.29791986 -1.50511347  0.        ]
#  [-0.71116177 -0.91085894  0.        ]
#  [-0.89029901  1.08798883  0.        ]
#  [-1.29628468  0.67894066  0.        ]
#  [ 0.70595703 -0.50201423  0.        ]
#  [ 0.51466098 -0.68114959  0.        ]
#  [-0.48188663  1.29761892  0.        ]
#  [-0.29517483  1.08232531  0.        ]
#  [-0.51355295 -1.10990977  0.        ]
#  [-1.28527997  0.90119301  0.        ]
#  [ 0.90717165  0.3090199   0.        ]
#  [-0.5047068  -0.69621987  0.        ]
#  [-0.70714453 -0.09048966  0.        ]
#  [ 0.08124031  0.49673394  0.        ]
#  [ 0.09398102 -0.49742187  0.        ]
#  [-0.91266783  0.2748329   0.        ]
#  [ 0.50161259  1.29598611  0.        ]
#  [-1.11840545 -0.68816139  0.        ]
#  [-0.48181281  0.30672492  0.        ]
#  [-1.50498213 -1.30766401  0.        ]
#  [-0.08958435 -0.30180921  0.        ]
#  [-1.09146262  0.89677893  0.        ]
#  [ 0.28704088 -1.50395403  0.        ]
#  [-1.0984433  -1.08120764  0.        ]
#  [-1.09099977  1.11220425  0.        ]
#  [-0.70052629 -0.50724691  0.        ]
#  [ 0.70754372  0.50630624  0.        ]
#  [ 0.89609235  0.8867888   0.        ]
#  [-0.30459964  0.08625479  0.        ]
#  [ 1.10524937  0.49435595  0.        ]
#  [ 0.10555713 -1.49279369  0.        ]
#  [-0.08884889  0.89370627  0.        ]
#  [-0.49535364 -0.88555479  0.        ]
#  [-1.49851314 -0.10612275  0.        ]
#  [ 1.09640597  1.30239156  0.        ]
#  [-1.51335127  1.08404398  0.        ]
#  [ 0.09196421  1.09687976  0.        ]
#  [-0.09697534 -0.49577243  0.        ]
#  [ 0.29730647  1.10569529  0.        ]
#  [ 1.28200388 -0.10063308  0.        ]
#  [-1.50489436  0.70339493  0.        ]
#  [ 0.11265837  0.89786135  0.        ]
#  [-0.10054278 -1.50659089  0.        ]
#  [ 1.30915543  0.28171682  0.        ]
#  [ 0.31707181 -1.30893753  0.        ]
#  [ 1.10341312 -0.70273915  0.        ]
#  [ 1.29819141  0.09181559  0.        ]
#  [-1.0912779  -0.30172628  0.        ]
#  [-1.09802783  0.0882677   0.        ]
#  [ 1.30040934 -0.28450974  0.        ]
#  [ 0.90633709 -0.50587516  0.        ]
#  [ 0.28201973 -0.89279866  0.        ]
#  [-0.28864991 -1.10752357  0.        ]
#  [-0.28006099 -0.70693761  0.        ]
#  [-0.89211661 -1.31141893  0.        ]
#  [ 1.31806134 -0.4985957   0.        ]
#  [-0.89867456  0.69772608  0.        ]
#  [-1.29433581 -1.31140447  0.        ]
#  [-1.29454298  0.31832924  0.        ]
#  [ 1.08693476  1.11042387  0.        ]
#  [-0.90270249 -0.29238525  0.        ]
#  [-1.09775417 -0.92014417  0.        ]
#  [ 0.10981389  0.6979008   0.        ]
#  [ 0.28565418 -0.09776629  0.        ]
#  [ 1.08678949  0.70869255  0.        ]
#  [-0.48874832  0.90071534  0.        ]
#  [-1.10344826  1.28473999  0.        ]
#  [-1.50535937 -0.51467939  0.        ]
#  [-0.49058827  1.0972944   0.        ]
#  [ 1.30146153  0.70739021  0.        ]
#  [ 0.50750419 -0.4980999   0.        ]
#  [-1.48206135 -0.29915313  0.        ]
#  [-0.69982392 -1.4811228   0.        ]
#  [-1.49271919 -1.10187119  0.        ]
#  [ 0.71117274 -0.30625113  0.        ]
#  [-0.89658826 -1.48470746  0.        ]
#  [-0.88606154 -0.89774422  0.        ]
#  [ 1.30443839  1.29547326  0.        ]
#  [-1.49818868  0.89681424  0.        ]
#  [ 0.69758863  1.08526582  0.        ]
#  [ 1.11183423 -0.29315776  0.        ]
#  [-0.69601846  0.10148021  0.        ]
#  [-1.10216684  0.32672305  0.        ]
#  [-0.51335374 -1.48742014  0.        ]
#  [ 0.51568837  1.09777037  0.        ]
#  [ 0.28565453  0.89975322  0.        ]
#  [-0.31629217  0.90897331  0.        ]
#  [-0.30643108 -0.50825883  0.        ]
#  [ 0.89247524  1.27960913  0.        ]
#  [ 0.69637394 -0.71320076  0.        ]
#  [-1.49841716 -0.88360666  0.        ]
#  [ 0.30778221  0.4986802   0.        ]
#  [ 0.30118161 -0.50017332  0.        ]
#  [-0.10976968 -0.69819953  0.        ]
#  [ 1.08919272 -1.48958794  0.        ]
#  [ 0.31056556 -0.69949889  0.        ]
#  [ 1.31036275 -1.29880108  0.        ]
#  [-0.90177068  1.31422728  0.        ]
#  [-0.7036809   0.70780853  0.        ]
#  [ 1.11866798  0.10539074  0.        ]
#  [-0.48983345 -0.08482311  0.        ]
#  [ 0.4942934  -1.50026112  0.        ]
#  [-0.89261373 -0.71134229  0.        ]
#  [-0.09258045 -1.10656689  0.        ]
#  [ 0.90459722 -1.47763597  0.        ]
#  [ 1.09938263 -0.89229677  0.        ]
#  [ 0.69533318 -0.89841601  0.        ]
#  [ 0.29867045  0.30766949  0.        ]
#  [ 0.88925713 -0.68675359  0.        ]
#  [-0.90526158 -1.12273114  0.        ]
#  [ 0.0971702  -1.08953222  0.        ]
#  [ 1.10167034  0.30925555  0.        ]
#  [-0.70329026 -0.69451363  0.        ]
#  [ 0.90084172  1.10781048  0.        ]
#  [ 0.50772107  0.8990971   0.        ]
#  [-0.2894163   0.69725612  0.        ]
#  [-0.68226954  1.31178568  0.        ]
#  [-0.9175236  -0.51207304  0.        ]
#  [-0.89093884  0.11827656  0.        ]
#  [-1.11708656 -0.09388382  0.        ]
#  [ 0.70094875  1.29807698  0.        ]
#  [-1.49928052 -1.50058136  0.        ]
#  [-1.30359379 -0.32203223  0.        ]
#  [-0.7068008  -0.29610992  0.        ]
#  [-1.29252006 -1.09576666  0.        ]
#  [-1.49680671  0.28157814  0.        ]
#  [-0.10472902  0.50417589  0.        ]
#  [ 0.70679748  0.69485906  0.        ]
#  [ 0.29051603 -1.10914417  0.        ]
#  [ 1.11129149 -0.0938031   0.        ]
#  [-0.67355447 -1.30337065  0.        ]
#  [ 0.89626617 -0.90948307  0.        ]
#  [ 0.89502502 -1.29167281  0.        ]
#  [-1.49634767 -0.70341039  0.        ]
#  [-0.50836494 -0.49854841  0.        ]
#  [ 0.09484171 -0.8673439   0.        ]
#  [ 0.89119496 -0.30695317  0.        ]
#  [-0.70274699  1.10897167  0.        ]
#  [-1.30981785  1.30255783  0.        ]
#  [-1.29411744 -0.09167004  0.        ]
#  [ 0.10848398  1.28894075  0.        ]
#  [-0.11043003 -0.9106199   0.        ]
#  [ 0.0999116   0.09847218  0.        ]
#  [-1.28524683 -0.49348067  0.        ]
#  [ 1.3200769  -0.9108208   0.        ]
#  [ 0.91426314  0.69074437  0.        ]
#  [ 1.10316229 -1.09703984  0.        ]
#  [ 0.50846653 -0.10764681  0.        ]
#  [-0.29619218 -0.3048596   0.        ]
#  [-0.68558807  0.49879702  0.        ]
#  [-0.11405719  1.30880837  0.        ]
#  [-0.1172898   1.08813949  0.        ]
#  [-1.31168915 -0.70742552  0.        ]
#  [-1.27827884  1.08471999  0.        ]
#  [ 1.29606232 -0.69458912  0.        ]
#  [ 0.49320694  0.69621097  0.        ]
#  [ 1.29788123  0.49481776  0.        ]
#  [-0.69417426  0.896407    0.        ]
#  [ 0.31196705 -0.29792314  0.        ]
#  [ 1.09885617 -0.49065918  0.        ]
#  [ 0.31901099  0.08240957  0.        ]
#  [-1.50427571  0.50342721  0.        ]
#  [-0.30189151  0.51761627  0.        ]
#  [-0.10667198  0.69886325  0.        ]
#  [ 0.71076735  0.09640685  0.        ]
#  [ 0.89686224  0.09105269  0.        ]
#  [-0.50906734  0.69155131  0.        ]
#  [ 1.29635989 -1.10615556  0.        ]
#  [ 0.29260796  1.29229597  0.        ]]
# distances: 225 [ 1.18797875  1.8903934   1.55487625  0.50165578  0.83961238  1.907527
#   1.89474225  1.92466315  0.85332636  0.86252301  1.19704143  0.86339265
#   0.49969718  0.16280337  0.82484838  1.56704259  0.17802661  0.87554021
#   0.20470014  0.51686563  1.20333367  0.13045741  1.26268347  2.2476629
#   1.57129893  0.90078019  2.27433542  2.23040099  1.20492159  1.24417789
#   0.13379437  1.18519527  0.1678769   1.55065023  2.58773693  0.89737546
#   1.90228137  1.21524105  0.50471988  0.20584262  0.87110246  2.24913087
#   0.17847746  1.86735409  1.5739293   2.24531873  0.90628612  0.86783659
#   0.55337359  0.17557587  2.23680457  2.266417    1.55598114  0.56311991
#   1.93989395  2.59114467  0.51601234  1.23176832  1.54204312  2.24523093
#   1.22275344  0.89141896  0.83465212  0.51125781  0.88949981  2.22617021
#   1.57126739  0.87417782  1.22481025  0.14071235  0.1627799   1.58078705
#   0.8688185   1.93713506  0.83452427  2.60670551  0.15516464  1.89046872
#   0.49716938  1.90255961  1.88966704  1.21334712  1.22550166  1.55207748
#   0.52758205  1.91434806  0.18283032  0.1538908   0.85797768  2.5955009
#   1.89903084  2.62120129  0.15928669  0.16796621  0.5149499   2.22049585
#   2.60655349  0.19513001  0.1741452   2.26752372  0.54918449  1.91116759
#   2.24853348  1.89014877  1.90183998  2.25237504  1.56982189  0.48847251
#   0.49995631  0.48507986  1.5451913   2.2829492   1.55655     2.24185539
#   2.24221422  1.88262623  1.56352657  1.901366    0.19020324  0.49476756
#   1.88237462  0.84653692  1.91122845  2.60735891  0.84972381  2.25419749
#   0.87902303  2.56700555  1.21213059  2.58546548  1.23178732  1.55293642
#   1.53470361  2.25935356  2.5949389   1.20825894  1.92575337  1.20553934
#   1.90900897  0.88915476  0.89319846  0.49476816  0.54783411  0.5307542
#   1.54581245  1.20615505  2.59533465  0.53309443  0.52166185  0.19012665
#   1.88653713  0.53791532  2.26961485  1.56191264  1.21881107  1.93758978
#   0.84841643  0.85614129  1.54605232  0.16035404  1.56680835  1.90418656
#   1.2043524   0.51731239  1.54023852  1.56795904  0.16830372  1.908149
#   1.21813446  1.56030363  0.8793987   0.50128374  1.18172551  1.58919749
#   1.54315134  1.93485068  1.21407885  2.59683003  2.25789068  1.2242149
#   2.23871041  2.59254527  0.18139599  1.22420914  0.50318852  1.92481332
#   1.16663057  1.55237855  1.5502288   2.59175018  0.88051391  0.16427065
#   1.54359495  1.2171935   2.26867106  2.24147716  0.18789977  0.19127043
#   0.17305197  2.2261128   2.28644026  1.58355022  1.91073313  0.88068987
#   0.51301991  1.18747336  0.19755284  0.20315189  2.27191226  2.21404389
#   2.24484579  0.85425948  2.24799624  1.2023451   0.54034278  1.90327471
#   0.55254325  2.60548196  0.52289144  0.18476129  1.23108516  1.55341096
#   0.8817305   2.24536119  0.50681185]
# LFP electrode tip location (x,y) in degrees: [0.0, 0.0, 0.0]
# [0.0, 0.2727272727272727, 0.5454545454545454, 0.8181818181818181, 1.0909090909090908, 1.3636363636363635, 1.6363636363636362, 1.909090909090909, 2.1818181818181817, 2.454545454545454, 2.727272727272727, 3.0]
# trials: 10
# Number of neurons considering 225
# idd 16064
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 25600
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 31936
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 31873
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 32065
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 32705
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 34241
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 37313
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 25346
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 33666
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 18755
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 22659
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 25859
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 35587
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 17924
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 29636
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 29764
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 37316
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 19077
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 22341
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 32133
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 37573
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 16390
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 23494
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 26950
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 28230
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 33222
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 37126
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 37318
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 31943
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 20168
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 25160
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 33864
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 23625
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 25865
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 28233
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 29001
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 17226
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 23691
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 31435
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 23692
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 24012
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 26060
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 19917
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 36301
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 24270
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 25614
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 25934
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 29454
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 36686
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 38094
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 38606
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 27087
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 32527
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 35343
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 21264
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 35344
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 28945
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 31569
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 33873
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 35217
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 37009
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 17170
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 18706
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 20882
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 29906
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 30098
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 35282
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 28307
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 31891
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 32019
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 19732
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 31892
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 24085
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 28309
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 30549
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 17302
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 19734
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 26839
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 30743
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 38039
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 17241
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 20633
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 28057
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 28249
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 30617
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 37657
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 21914
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 30874
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 35418
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 38490
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 19739
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 25883
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 26779
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 36059
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 17884
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 29532
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 17501
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 29085
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 33054
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 19551
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 26143
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 27167
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 30239
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 35935
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 16608
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 26912
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 29024
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 31712
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 34208
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 36064
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 27425
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 29217
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 30305
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 36194
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 20451
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 20708
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 25892
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 30244
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 30564
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 31588
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 36452
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 37284
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 23589
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 30693
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 37733
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 25638
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 30054
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 30566
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 36134
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 21607
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 34663
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 36519
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 19560
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 26024
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 26792
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 33000
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 36200
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 21929
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 20138
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 21610
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 25002
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 25834
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 28842
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 22827
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 27243
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 31275
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 22828
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 23916
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 24172
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 38444
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 15405
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 32429
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 15022
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 26030
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 32494
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 34606
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 37166
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 22639
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 23791
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 29295
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 29551
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 34415
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 36015
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 15856
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 21808
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 25328
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 31152
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 32432
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 38640
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 29425
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 29681
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 36337
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 15986
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 16690
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 18674
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 18994
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 21554
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 32626
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 34930
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 38002
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 19059
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 19635
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 28211
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 34739
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 18228
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 22260
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 24052
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 28852
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 35700
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 37364
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 38516
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 30901
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 33781
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 35381
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 23990
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 28918
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 29366
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 31286
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 22327
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 22136
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 23864
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 24760
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 33528
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 19129
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 24569
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 25273
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 26425
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 31865
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 18618
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 29946
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 33082
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 36730
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 38139
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 15164
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 16572
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 32316
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 34876
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 38524
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 19453
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 27389
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 27070
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 33278
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 17919
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 31359
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# (225,)
# (225, 12, 2003)
# LFP: (12, 2003) -106.448141934 -332.615595573 -25.6162907556
# folder:  /home/antolikjan/remote/UNIC/dev/pkg/mozaik/mozaik/contrib/New/20190912-113106[param_FINAL.defaults]CombinationParamSearch{sheets.l4_cortex_exc.K:[1000]}/SelfSustainedPushPull_ParameterSearch_____sheets.l4_cortex_exc.K:1000
# sheet:  V1_Exc_L2/3
# 120
# Recorded neurons: 225 [61440 45761 46465 47681 51010 54018 57090 62660 66564 67012 67332 67972
#  50437 54085 55237 56197 45830 46982 49158 51334 62342 61511 61831 68423
#  47560 67016 67720 51017 52105 53449 53514 62154 62922 45771 51467 56267
#  52492 57612 63180 48077 49549 53133 58381 50446 52622 55950 62479 48784
#  45393 52625 57041 61841 62801 65041 51346 54738 63442 64466 55571 65235
#  68499 55380 50645 59285 60373 62741 65301 66965 68117 47830 50134 51798
#  58390 59350 61078 65686 68374 56983 66839 62424 68376 68440 46425 49497
#  51097 56217 64857 45146 51482 55258 65946 66586 53979 65051 66907 52764
#  55964 58524 62172 65372 49373 50909 51357 56797 60061 65181 66269 57054
#  64478 55711 57183 59359 61215 63775 54880 63584 64672 56737 64225 48866
#  51106 58786 47843 49251 51747 56483 61732 53733 56805 65317 61926 68006
#  46631 59431 65703 63272 67432 50985 59689 63977 66537 50794 63018 63594
#  66666 51115 59307 49836 50412 56748 61549 65837 48238 63342 59055 61039
#  63279 65071 67631 48496 49200 53872 60400 60912 64944 46897 51761 53489
#  60017 48498 51506 56882 60658 51827 53107 57267 63347 66291 52468 57012
#  59828 61812 62132 54069 57781 58613 60917 49590 58806 62262 66678 48055
#  51895 58423 63479 63863 68599 49976 57080 57784 61816 64760 68729 60410
#  62394 62522 66810 55355 56379 58683 66427 68987 54396 55228 58812 63484
#  65852 54909 58749 63165 56638 57150 61694 47551 54143]
# (3, 24000)
# (225, 3)
# [[ 0.71240142 -0.7055896   0.        ]
#  [ 0.32256946  0.49830823  0.        ]
#  [ 0.89868525  0.10462952  0.        ]
#  [-1.08844446 -1.09771064  0.        ]
#  [ 0.89624087 -1.29387796  0.        ]
#  [-1.1116445   1.29504122  0.        ]
#  [-1.27962933  0.88187227  0.        ]
#  [-0.89141016 -1.30289865  0.        ]
#  [ 0.30209783 -0.9039369   0.        ]
#  [-0.67686554 -0.11539823  0.        ]
#  [ 0.50650802 -1.11191803  0.        ]
#  [-0.50532152  0.32210187  0.        ]
#  [-0.89774039  1.31183529  0.        ]
#  [ 0.09850404  0.89880594  0.        ]
#  [ 0.70402001 -0.89187261  0.        ]
#  [-0.08536467 -0.09963142  0.        ]
#  [-1.28379004  1.30399353  0.        ]
#  [-1.48066072  0.10175954  0.        ]
#  [-1.27955537 -0.29962916  0.        ]
#  [ 1.29503222 -0.4927701   0.        ]
#  [-0.48366416 -1.51839771  0.        ]
#  [ 1.29861994 -0.90796073  0.        ]
#  [-0.89835807 -1.51523558  0.        ]
#  [ 0.69410967  0.68460291  0.        ]
#  [-1.31037319 -0.50334508  0.        ]
#  [ 0.69922236 -1.29441243  0.        ]
#  [ 1.30886523  0.08852577  0.        ]
#  [-1.50208287 -0.72028206  0.        ]
#  [ 0.10534039 -0.68623608  0.        ]
#  [-1.50640212 -0.49697214  0.        ]
#  [-0.90140553  0.49057219  0.        ]
#  [ 1.27349942 -1.49894218  0.        ]
#  [-0.29029129 -1.49996929  0.        ]
#  [-1.29972501  0.70105652  0.        ]
#  [-0.4924356  -1.08248366  0.        ]
#  [-0.69263219  1.09863857  0.        ]
#  [-0.09937534 -1.10193251  0.        ]
#  [ 1.30071069  0.51302288  0.        ]
#  [ 0.10329506  1.30254715  0.        ]
#  [-0.90758823 -0.10896866  0.        ]
#  [-1.1089437   0.90100196  0.        ]
#  [-0.91971395  0.08972786  0.        ]
#  [-0.48714499  0.50236101  0.        ]
#  [ 1.10029768 -1.48898932  0.        ]
#  [-0.2911263   0.30121951  0.        ]
#  [ 0.68802822  1.09445875  0.        ]
#  [ 0.50089363 -1.30322414  0.        ]
#  [-0.29845111  0.89150276  0.        ]
#  [ 1.30119214  1.29849722  0.        ]
#  [-1.49091846 -1.31170096  0.        ]
#  [ 0.29985467 -1.10804008  0.        ]
#  [-0.6977008  -1.10202488  0.        ]
#  [ 0.301839   -0.70780102  0.        ]
#  [-0.30702449 -1.30196982  0.        ]
#  [-1.09517278  0.09243898  0.        ]
#  [-0.69621581 -1.3072389   0.        ]
#  [ 0.89807752  0.88374359  0.        ]
#  [ 0.2971702  -0.09900768  0.        ]
#  [-1.10047368  0.48163054  0.        ]
#  [-0.29601954 -1.11449477  0.        ]
#  [-0.49376628 -0.4876053   0.        ]
#  [-0.49759995  0.09704934  0.        ]
#  [-0.69284338 -0.31356013  0.        ]
#  [ 0.11153225 -0.88980719  0.        ]
#  [ 1.30744306 -1.10001736  0.        ]
#  [-0.28873642 -0.90021257  0.        ]
#  [ 0.91307797  1.29060984  0.        ]
#  [-0.51503462  1.30901859  0.        ]
#  [-1.09897087  1.1019544   0.        ]
#  [ 0.09031223 -0.2881938   0.        ]
#  [-0.11317835  0.91105638  0.        ]
#  [ 0.70762686  1.29876419  0.        ]
#  [-1.49570622  0.68899865  0.        ]
#  [-0.69087395 -1.4978155   0.        ]
#  [-0.28651552  0.51668632  0.        ]
#  [-1.11760428  0.28653219  0.        ]
#  [ 0.7203789  -0.50174319  0.        ]
#  [-1.47603851  1.29955108  0.        ]
#  [-1.09190843 -0.70481638  0.        ]
#  [-0.69220557  0.32297747  0.        ]
#  [ 1.09419148  0.88646235  0.        ]
#  [-0.08899154  0.10220605  0.        ]
#  [-1.10735614 -0.29012633  0.        ]
#  [-0.50466217  1.08094222  0.        ]
#  [ 0.50889977 -0.69942237  0.        ]
#  [-0.2946442  -0.69704831  0.        ]
#  [ 0.48372091  1.09540194  0.        ]
#  [-0.5084742  -1.31375406  0.        ]
#  [ 0.50117414 -1.49661258  0.        ]
#  [-1.09738696 -0.92261681  0.        ]
#  [ 1.31341728 -1.29002874  0.        ]
#  [ 0.28034138  0.69504259  0.        ]
#  [ 0.11049543  0.29046879  0.        ]
#  [-0.71021774  1.30233119  0.        ]
#  [ 0.90304967 -0.29975272  0.        ]
#  [-0.49957062  0.69676356  0.        ]
#  [-0.10069006 -0.88982668  0.        ]
#  [ 0.31484862 -0.48898901  0.        ]
#  [-1.30493825  0.09666343  0.        ]
#  [ 0.69364296  0.29261602  0.        ]
#  [-1.09308639 -0.48496923  0.        ]
#  [-0.89127124 -0.69695572  0.        ]
#  [-0.89594275 -0.8903352   0.        ]
#  [ 0.29857819  0.8979627   0.        ]
#  [-1.49841793 -0.30726417  0.        ]
#  [-1.29636757 -0.10861226  0.        ]
#  [-0.1010995   0.29503879  0.        ]
#  [ 0.5027889   0.12434204  0.        ]
#  [-0.10759062 -0.6942062   0.        ]
#  [ 1.09769307  1.10007409  0.        ]
#  [ 0.30803673 -0.30709447  0.        ]
#  [-0.29840647 -0.31268106  0.        ]
#  [ 0.90886052 -0.09476572  0.        ]
#  [ 0.31484921  0.10145571  0.        ]
#  [-1.29798358 -1.48602964  0.        ]
#  [-0.49555778 -0.70948529  0.        ]
#  [ 1.10350202 -1.29879359  0.        ]
#  [ 0.29137022 -1.30057308  0.        ]
#  [-0.31120855 -0.11097807  0.        ]
#  [ 0.68757979  0.10260037  0.        ]
#  [ 0.92073148 -1.49929429  0.        ]
#  [-1.49958881  1.1250657   0.        ]
#  [ 0.09705135 -0.08547839  0.        ]
#  [-1.31221224  1.1051705   0.        ]
#  [ 1.08654466 -0.51356171  0.        ]
#  [ 0.3065167   0.29771683  0.        ]
#  [ 1.08933232  0.10520404  0.        ]
#  [-0.9010543   0.69614314  0.        ]
#  [ 1.08350353 -0.89661116  0.        ]
#  [ 0.32365208  1.09958025  0.        ]
#  [-0.31588493  1.30384113  0.        ]
#  [-0.70778877  0.11209069  0.        ]
#  [ 0.5067227   0.49373378  0.        ]
#  [-0.48724871 -0.28563993  0.        ]
#  [ 0.51018822  0.693584    0.        ]
#  [-0.26981754  0.73349699  0.        ]
#  [ 1.2937151   1.11005533  0.        ]
#  [ 0.11122548 -1.3011598   0.        ]
#  [ 0.50706135 -0.50078035  0.        ]
#  [-1.49060824  0.91088974  0.        ]
#  [-1.51824963 -1.50391839  0.        ]
#  [ 0.50801787 -0.28871926  0.        ]
#  [ 0.6881296  -0.08660885  0.        ]
#  [-0.52533266 -0.11974291  0.        ]
#  [-0.10590206  1.11133744  0.        ]
#  [ 1.30317556 -0.30569488  0.        ]
#  [-1.28597589 -0.90907145  0.        ]
#  [ 1.08964161 -0.70364139  0.        ]
#  [-1.5082362   0.30105593  0.        ]
#  [ 0.69252471  0.88946026  0.        ]
#  [-0.08133879 -0.31449849  0.        ]
#  [ 0.89661193 -1.08673491  0.        ]
#  [-0.90125229 -1.11355159  0.        ]
#  [-0.30316256  0.10012385  0.        ]
#  [ 1.10800805 -0.09098719  0.        ]
#  [-0.49508246 -0.88631203  0.        ]
#  [-1.49221363 -0.90265681  0.        ]
#  [-1.28771867 -1.3084417   0.        ]
#  [ 0.49683109 -0.1105941   0.        ]
#  [ 0.69378361  0.49603854  0.        ]
#  [-0.30511069 -0.48972101  0.        ]
#  [-1.51673902 -0.11517511  0.        ]
#  [ 0.50592991  0.30151385  0.        ]
#  [-0.10563862 -1.29995268  0.        ]
#  [ 0.90560921  0.30172225  0.        ]
#  [-0.09215924  0.71628296  0.        ]
#  [ 1.08883524  0.29395466  0.        ]
#  [-0.70455752 -0.49607634  0.        ]
#  [-0.88635856 -0.32902006  0.        ]
#  [-0.70382842  0.9060226   0.        ]
#  [ 0.89623971 -0.69658164  0.        ]
#  [-1.29376423 -1.10484649  0.        ]
#  [ 0.69643208 -1.08952504  0.        ]
#  [ 0.70604851 -0.30202876  0.        ]
#  [-1.08324496 -1.50379784  0.        ]
#  [-1.29586113  0.28613282  0.        ]
#  [ 0.91016411 -0.88975752  0.        ]
#  [-0.10835311 -1.50076136  0.        ]
#  [-0.10241553  0.51481441  0.        ]
#  [ 0.10698002 -1.51186701  0.        ]
#  [ 0.3003071  -1.49662879  0.        ]
#  [-1.50112698  0.49045523  0.        ]
#  [-1.0859789  -0.0911926   0.        ]
#  [-1.10714184  0.69821683  0.        ]
#  [-1.30533482 -0.713906    0.        ]
#  [ 1.30386739  0.69003264  0.        ]
#  [ 1.31035883 -0.69052313  0.        ]
#  [ 0.90106267  0.69968663  0.        ]
#  [ 1.08616453  0.70006631  0.        ]
#  [-0.29783952  1.11066044  0.        ]
#  [-1.29477429  0.50117066  0.        ]
#  [-0.89629211  0.89021869  0.        ]
#  [ 0.30751622  1.31087794  0.        ]
#  [-1.52475796 -1.11716252  0.        ]
#  [ 1.10293985  1.28793178  0.        ]
#  [ 0.09462161 -1.08844774  0.        ]
#  [-0.7097678   0.51179622  0.        ]
#  [ 0.69823976 -1.49381945  0.        ]
#  [ 0.1034664   0.51101605  0.        ]
#  [ 1.29852439  0.30456171  0.        ]
#  [-0.7097559   0.6908501   0.        ]
#  [ 1.08556004  0.50237764  0.        ]
#  [ 0.1093114  -0.49800294  0.        ]
#  [ 1.09585384 -1.10606145  0.        ]
#  [ 0.11265742  0.71410926  0.        ]
#  [-0.90260033 -0.49766939  0.        ]
#  [-0.51478971  0.8791401   0.        ]
#  [ 1.29131192 -0.1093201   0.        ]
#  [-0.71279281 -0.69660241  0.        ]
#  [-0.70563514 -0.88786949  0.        ]
#  [-1.10583847 -1.29607149  0.        ]
#  [ 0.49208794 -0.92308177  0.        ]
#  [ 0.5276741   1.28916103  0.        ]
#  [-0.90231883  0.30431059  0.        ]
#  [ 1.09213823 -0.30925447  0.        ]
#  [-0.07759694  1.29810286  0.        ]
#  [ 0.90453247  0.52338762  0.        ]
#  [ 0.09803696  1.09500711  0.        ]
#  [ 0.49260959  0.88749109  0.        ]
#  [-0.10712013 -0.51221421  0.        ]
#  [ 0.89740369  1.12848702  0.        ]
#  [ 0.89157634 -0.52700976  0.        ]
#  [-0.89564059  1.10694286  0.        ]
#  [ 0.0971374   0.12756944  0.        ]
#  [ 1.2971163   0.91326161  0.        ]]
# distances: 225 [ 1.23391545  0.55870669  1.55656852  1.8852411   1.55233472  1.92542475
#   2.21638301  1.54396769  0.52324879  1.1723655   0.87729763  0.87524254
#   1.55493196  0.170614    1.21939842  0.14785594  2.22358958  2.56457959
#   2.21625491  2.24306161  0.8377309   2.24927571  1.55600181  1.20223321
#   2.26963295  1.21108865  2.26702107  2.60168384  0.1824549   2.60916501
#   1.56128018  2.2057657   0.50279926  2.25118975  0.85292348  1.19967414
#   0.17212313  2.25289701  0.1789123   1.57198892  1.92074682  1.59299128
#   0.84375988  1.90577149  0.50424554  1.19169984  0.86757321  0.51693248
#   2.2537309   2.58234652  0.51936353  1.20845323  0.52280049  0.53178201
#   1.8968949   1.20588115  1.55551589  0.51471388  1.90607632  0.51272089
#   0.85522828  0.8618684   1.20003994  0.19317953  2.26455781  0.50010615
#   1.58149743  0.89206612  1.90347338  0.15642537  0.19603065  1.22564567
#   2.59063917  1.19662878  0.49625945  1.93574739  1.24773286  2.55657369
#   1.89124089  1.19893521  1.89519524  0.15413787  1.9179971   0.87410052
#   0.88144026  0.51033872  0.83782919  0.88070315  0.86805907  1.90072996
#   2.27490545  0.48556551  0.1913837   1.2301332   1.56412792  0.86528169
#   0.17440029  0.54533381  2.26021935  1.20142485  1.89328117  1.54372707
#   1.55181837  0.51715259  2.59533598  2.24537449  0.17510947  0.87085591
#   0.18635242  1.90126016  0.53353526  0.51685517  1.57419261  0.54533483
#   2.2481735   0.85833126  1.91132157  0.50466802  0.53902903  1.19092313
#   1.5947537   2.597364    0.16809787  2.27281828  1.88195055  0.53090251
#   1.88677892  1.56067183  1.87668316  0.56058185  0.54712874  1.22592611
#   0.87766946  0.84393952  0.88367192  0.46733769  2.24078029  0.19264819
#   0.87825603  2.5818092   2.6296855   0.87991277  1.19187543  0.90990285
#   0.18342774  2.25716629  2.22737558  1.88731464  2.61234173  1.19948798
#   0.14088292  1.55297743  1.56101476  0.52509296  1.91912624  0.85750798
#   2.58458982  2.23039417  0.86053669  1.20166846  0.52846722  2.62706905
#   0.8762963   0.18297145  1.56856117  0.15962449  1.88591796  1.22032942
#   1.53521805  1.21906658  1.55233272  2.24086537  1.20625575  1.2229119
#   1.87623531  2.24449731  1.57645048  0.18767308  0.1773889   0.18529483
#   0.52014716  2.60002819  1.88097063  1.91762592  2.26090623  2.25836457
#   2.26960807  1.56068633  1.88129216  0.51587318  2.24261486  1.55242347
#   0.53263373  2.64095826  1.91034785  0.16388944  1.2293539   1.20938674
#   0.17920906  2.24911022  1.22933328  1.88024514  0.1893329   1.89807453
#   0.19512838  1.56334962  0.89164193  2.23661785  1.23459337  1.22219591
#   1.91536841  0.85232132  0.91395835  1.56286206  1.89163891  0.13440185
#   1.5666962   0.16980499  0.85322484  0.18553751  1.55434878  1.54425551
#   1.55129501  0.1682469   2.24667134]
# LFP electrode tip location (x,y) in degrees: [0.0, 0.0, 0.0]
# [0.0, 0.2727272727272727, 0.5454545454545454, 0.8181818181818181, 1.0909090909090908, 1.3636363636363635, 1.6363636363636362, 1.909090909090909, 2.1818181818181817, 2.454545454545454, 2.727272727272727, 3.0]
# trials: 10
# Number of neurons considering 225
# idd 61440
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 45761
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 46465
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 47681
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 51010
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 54018
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 57090
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 62660
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 66564
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 67012
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 67332
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 67972
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 50437
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 54085
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 55237
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 56197
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 45830
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 46982
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 49158
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 51334
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 62342
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 61511
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 61831
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 68423
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 47560
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 67016
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 67720
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 51017
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 52105
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 53449
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 53514
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 62154
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 62922
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 45771
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 51467
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 56267
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 52492
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 57612
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 63180
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 48077
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 49549
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 53133
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 58381
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 50446
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 52622
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 55950
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 62479
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 48784
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 45393
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 52625
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 57041
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 61841
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 62801
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 65041
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 51346
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 54738
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 63442
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 64466
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 55571
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 65235
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 68499
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 55380
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 50645
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 59285
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 60373
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 62741
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 65301
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 66965
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 68117
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 47830
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 50134
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 51798
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 58390
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 59350
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 61078
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 65686
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 68374
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 56983
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 66839
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 62424
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 68376
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 68440
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 46425
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 49497
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 51097
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 56217
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 64857
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 45146
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 51482
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 55258
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 65946
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 66586
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 53979
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 65051
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 66907
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 52764
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 55964
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 58524
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 62172
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 65372
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 49373
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 50909
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 51357
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 56797
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 60061
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 65181
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 66269
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 57054
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 64478
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 55711
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 57183
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 59359
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 61215
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 63775
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 54880
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 63584
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 64672
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 56737
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 64225
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 48866
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 51106
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 58786
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 47843
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 49251
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 51747
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 56483
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 61732
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 53733
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 56805
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 65317
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 61926
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 68006
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 46631
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 59431
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 65703
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 63272
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 67432
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 50985
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 59689
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 63977
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 66537
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 50794
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 63018
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 63594
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 66666
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 51115
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 59307
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 49836
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 50412
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 56748
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 61549
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 65837
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 48238
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 63342
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 59055
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 61039
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 63279
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 65071
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 67631
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 48496
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 49200
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 53872
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 60400
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 60912
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 64944
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 46897
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 51761
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 53489
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 60017
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 48498
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 51506
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 56882
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 60658
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 51827
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 53107
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 57267
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 63347
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 66291
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 52468
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 57012
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 59828
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 61812
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 62132
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 54069
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 57781
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 58613
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 60917
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 49590
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 58806
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 62262
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 66678
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 48055
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 51895
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 58423
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 63479
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 63863
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 68599
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 49976
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 57080
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 57784
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 61816
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 64760
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 68729
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 60410
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 62394
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 62522
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 66810
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 55355
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 56379
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 58683
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 66427
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 68987
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 54396
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 55228
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 58812
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 63484
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 65852
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 54909
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 58749
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 63165
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 56638
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 57150
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 61694
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 47551
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# idd 54143
# len full_gsyn_e 120
# shape gsyn_e[0] (2003,)
# (225,)
# (225, 12, 2003)
# LFP: (12, 2003) -86.712805498 -280.092145272 -19.7479808146
