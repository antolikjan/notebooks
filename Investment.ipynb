# %%
import numpy
import pylab
my_data = numpy.genfromtxt('/home/antolikjan/Downloads/^GSPC (1).csv', delimiter=',')
keys = ['Date','Open','High','Low','Close','Adj Close','Volume']

# %%
numpy.shape(my_data)
# Out:
# (23110, 7)

# %%
pylab.figure()
pylab.plot(my_data[:10000,2])

# %%
def
